# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.cluster import KMeans
from sklearn.model_selection import GridSearchCV
# %pylab inline
import matplotlib.mlab as mlab
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
import seaborn as sns
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
master = pd.read_csv('Data/master_updated.csv')
master = master.rename(columns={'Unnamed: 0':'District'})

# %%
len(master)
# Out:
# 75

# %%
master.columns
# Out:
# Index([u'District', u'Foreigner', u'Hill Brahman', u'Hill Chhetree',
#        u'Hill Dalit', u'Madhesi Brahman/Chhetree', u'Madhesi Dalit',
#        u'Madhesi Other - OC A', u'Madhesi Other - OC B',
#        u'Mtn/Hill Janajati A', u'Mtn/Hill Janajati B', u'Musalman', u'Newar',
#        u'Other (MPB)', u'Other undefined', u'Tarai Janajati',
#        u'Total Pop Census', u'Poverty Gap', u'Poverty Incidence',
#        u'Poverty Severity', u'Adult illiteracy rate',
#        u'Deprivation in economic provisioning', u'HPI',
#        u'People not expected to survive age 40',
#        u'Children <5 years malnourished', u'Without safe water', u'BCG3',
#        u'DPT-HepB 1 3', u'DPT-HepB 2 3', u'DPT-HepB 3 3',
#        u'Japenese Encephalitis 3', u'Measles 12-23 3',
#        u'Measles 9-11 months 3', u'Polio13', u'Polio23', u'Polio33', u'TT 1 3',
#        u'TT 2+ 3', u'TT23', u'Sanitation Coverage (%',
#        u'Water Coverage Supply (%)', u'HDI ',
#        u'Sex Ratio (male per 100 female)', u'Confirmed Meningitis 3',
#        u'HIV/AIDS3', u'Leprosy3', u'STD/STI3', u'Acute Flacid Paralysis',
#        u'Chicken pox', u'Diptheria', u'Hepatatis-B', u'Measles', u'Mumps',
#        u'Neonatal Tetanus', u'Rubella', u'Tetanus', u'Tuberculosis',
#        u'Whooping cough', u'Alcoholism', u'Anxiety (Neurosis',
#        u'Conversive disorder\n(Hysteria)', u'Depression', u'Epilesy',
#        u'Mental retardation', u'Psychosis'],
#       dtype='object')

# %%
cols = master.columns.tolist()
#print(cols)
master = master.rename(columns={'TT 2+ 3':'TT2plus3', 'STD/STI3':'STD', 'HIV/AIDS3':'HIVAIDS'})
master.rename(columns=lambda x: x.replace(' ',''), inplace=True)
master.rename(columns=lambda x: x.replace('/',''), inplace=True)
master.rename(columns=lambda x: x.replace('(',''), inplace=True)
master.rename(columns=lambda x: x.replace(')',''), inplace=True)
master.rename(columns=lambda x: x.replace('-',''), inplace=True)
master.rename(columns=lambda x: x.replace('%',''), inplace=True)
master.rename(columns=lambda x: x.replace('+',''), inplace=True)
master.rename(columns=lambda x: x.replace('<',''), inplace=True)
master = master.drop('Peoplenotexpectedtosurviveage40',axis=1)
x = master.iloc[:,:41]
std = master['STD']
hiv = master['HIVAIDS']
hivstd = pd.concat([x, std, hiv], axis=1)

hivstd.head(2)
# Out:
#        District  Foreigner  HillBrahman  HillChhetree  HillDalit  \
# 0        Achham        0.0     0.102036      0.581749   0.135158
# 1  Arghakhanchi        0.0     0.327665      0.193248   0.209020
#
#    MadhesiBrahmanChhetree  MadhesiDalit  MadhesiOtherOCA  MadhesiOtherOCB  \
# 0                0.000101      0.000000         0.004921              0.0
# 1                0.001604      0.000066         0.001058              0.0
#
#    MtnHillJanajatiA   ...      Polio23   Polio33      TT13  TT2plus3  \
# 0          0.006921   ...     0.029579  0.029443  0.006622  0.016988
# 1          0.193349   ...     0.023377  0.023797  0.006097  0.011162
#
#        TT23  SanitationCoverage  WaterCoverageSupply    HDI       STD  HIVAIDS
# 0  0.007410               19.08                88.01  0.378  0.002750  0.00336
# 1  0.011481               46.20                82.97  0.482  0.003334  0.00000
#
# [2 rows x 43 columns]

# %%
std2 = pd.concat([x, std], axis=1)
hiv2 = pd.concat([x, hiv], axis=1)

# %% [markdown]
# ### random forest model for std
# No parameter tuning

# %%
rfr = RandomForestRegressor(random_state=100,oob_score=True)
rfr.fit(std2.iloc[:,1:41], std2['STD'])
print rfr.score(std2.iloc[:,1:41], std2['STD'])
print rfr.oob_score_
# Out:
# 0.798034791219
# -0.560074075026
# /Users/kristikorsberg/devel/venv/lib/python2.7/site-packages/sklearn/ensemble/forest.py:723: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "

# %%
estimates = pd.DataFrame()
estimates['vars'] = [elem for elem in std2.columns[1:41]]
estimates['sig'] = rfr.feature_importances_
estimates.sort_values(by='sig')
# Out:
#                                  vars       sig
# 2                        HillChhetree  0.000000
# 17                   PovertyIncidence  0.000000
# 37                 SanitationCoverage  0.000567
# 24                               BCG3  0.001625
# 20  Deprivationineconomicprovisioning  0.001766
# 13                     Otherundefined  0.001773
# 33                            Polio33  0.002726
# 25                          DPTHepB13  0.002831
# 12                           OtherMPB  0.003544
# 26                          DPTHepB23  0.004331
# 27                          DPTHepB33  0.004679
# 39                                HDI  0.005783
# 4              MadhesiBrahmanChhetree  0.006953
# 5                        MadhesiDalit  0.007415
# 0                           Foreigner  0.007602
# 23                   Withoutsafewater  0.008717
# 1                         HillBrahman  0.010585
# 31                            Polio13  0.011137
# 19                Adultilliteracyrate  0.011303
# 8                    MtnHillJanajatiA  0.013665
# 29                       Measles12233  0.015157
# 9                    MtnHillJanajatiB  0.016402
# 30                  Measles911months3  0.016919
# 7                     MadhesiOtherOCB  0.017813
# 34                               TT13  0.019595
# 28              JapeneseEncephalitis3  0.019839
# 32                            Polio23  0.026091
# 10                           Musalman  0.038299
# 36                               TT23  0.038544
# 21                                HPI  0.039534
# 6                     MadhesiOtherOCA  0.044387
# 14                      TaraiJanajati  0.044931
# 3                           HillDalit  0.045498
# 16                         PovertyGap  0.047903
# 35                           TT2plus3  0.048088
# 38                WaterCoverageSupply  0.056051
# 18                    PovertySeverity  0.068070
# 22         Children5yearsmalnourished  0.082919
# 11                              Newar  0.083855
# 15                     TotalPopCensus  0.123102

# %%
mse = pd.DataFrame()
mse['district'] = std2['District']
mse['actual'] = std2['STD']
mse['pred'] = rfr.oob_score_
mse['error'] = np.abs(mse['actual']-mse['pred'])
mse.sort_values(by='error')
# Out:
#          district    actual      pred     error
# 57      Rupandehi  0.000000 -0.560074  0.560074
# 35       Lalitpur  0.000000 -0.560074  0.560074
# 50          Parsa  0.000000 -0.560074  0.560074
# 44    Nawalparasi  0.000076 -0.560074  0.560150
# 65     Solukhumbu  0.000132 -0.560074  0.560206
# 46    Okhaldhunga  0.000189 -0.560074  0.560263
# 49         Parbat  0.000225 -0.560074  0.560299
# 66        Sunsari  0.000272 -0.560074  0.560347
# 24           Ilam  0.000365 -0.560074  0.560439
# 43         Myagdi  0.000370 -0.560074  0.560444
# 52      Ramechhap  0.000474 -0.560074  0.560548
# 64         Siraha  0.000485 -0.560074  0.560559
# 59  Sankhuwasabha  0.000510 -0.560074  0.560584
# 9       Bhaktapur  0.000525 -0.560074  0.560599
# 62       Sindhuli  0.000540 -0.560074  0.560614
# 48      Panchthar  0.000553 -0.560074  0.560627
# 47          Palpa  0.000685 -0.560074  0.560759
# 10        Bhojpur  0.000729 -0.560074  0.560803
# 17        Dhanusa  0.000745 -0.560074  0.560819
# 36        Lamjung  0.000769 -0.560074  0.560843
# 21         Gorkha  0.000793 -0.560074  0.560867
# 34        Khotang  0.000882 -0.560074  0.560956
# 41           Mugu  0.000922 -0.560074  0.560997
# 51        Pyuthan  0.000938 -0.560074  0.561012
# 4         Bajhang  0.000989 -0.560074  0.561063
# 40         Morang  0.000993 -0.560074  0.561067
# 16       Dhankuta  0.001010 -0.560074  0.561084
# 61        Sarlahi  0.001033 -0.560074  0.561107
# 45        Nuwakot  0.001078 -0.560074  0.561152
# 69         Tanahu  0.001083 -0.560074  0.561157
# ..            ...       ...       ...       ...
# 28        Kailali  0.001841 -0.560074  0.561915
# 38      Makwanpur  0.001941 -0.560074  0.562015
# 32          Kaski  0.002020 -0.560074  0.562094
# 19          Dolpa  0.002044 -0.560074  0.562118
# 31     Kapilbastu  0.002051 -0.560074  0.562125
# 3         Baitadi  0.002065 -0.560074  0.562139
# 58         Salyan  0.002099 -0.560074  0.562174
# 5          Bajura  0.002135 -0.560074  0.562209
# 56          Rukum  0.002138 -0.560074  0.562212
# 29        Kalikot  0.002169 -0.560074  0.562243
# 55          Rolpa  0.002383 -0.560074  0.562457
# 22          Gulmi  0.002388 -0.560074  0.562462
# 72       Udayapur  0.002463 -0.560074  0.562537
# 14           Dang  0.002534 -0.560074  0.562608
# 6           Banke  0.002565 -0.560074  0.562639
# 39         Manang  0.002600 -0.560074  0.562674
# 53         Rasuwa  0.002633 -0.560074  0.562707
# 0          Achham  0.002750 -0.560074  0.562824
# 13        Dailekh  0.002751 -0.560074  0.562825
# 74          Kavre  0.002820 -0.560074  0.562894
# 18        Dolakha  0.002932 -0.560074  0.563006
# 37      Mahottari  0.002957 -0.560074  0.563031
# 15        Dhading  0.003065 -0.560074  0.563139
# 1    Arghakhanchi  0.003334 -0.560074  0.563409
# 26          Jhapa  0.003562 -0.560074  0.563636
# 67        Surkhet  0.004156 -0.560074  0.564230
# 8         Bardiya  0.004335 -0.560074  0.564409
# 42        Mustang  0.005204 -0.560074  0.565278
# 23          Humla  0.008081 -0.560074  0.568155
# 12     Dadeldhura  0.008558 -0.560074  0.568632
#
# [75 rows x 4 columns]

# %% [markdown]
# Parameter tuning

# %%
#https://www.analyticsvidhya.com/blog/2015/06/tuning-random-forest-model/
model = RandomForestRegressor()
vals = {'n_estimators':[1, 5, 9],'max_features':[.1, .2, .3], 'min_samples_leaf':[10, 15, 20], \
       'n_jobs':[-1], 'oob_score':[True], 'random_state':[1, 2, 3]}
grid = GridSearchCV(estimator=model, param_grid=vals)
grid.fit(std2.iloc[:,1:41], std2['STD'])
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'oob_score': [True], 'n_jobs': [-1], 'min_samples_leaf': [10, 15, 20], 'n_estimators': [1, 5, 9], 'random_state': [1, 2, 3], 'max_features': [0.1, 0.2, 0.3]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=0)

# %%
print grid.best_estimator_.n_estimators
print grid.best_estimator_.max_features
print grid.best_estimator_.min_samples_leaf
print grid.best_estimator_.random_state
print grid.best_score_
# Out:
# 5
# 0.1
# 15
# 1
# -0.0445457085307

# %%
best = grid.best_estimator_
best.fit(std2.iloc[:,1:41], std2['STD'])
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=0.1, max_leaf_nodes=None, min_impurity_split=1e-07,
#            min_samples_leaf=15, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=5, n_jobs=-1,
#            oob_score=True, random_state=1, verbose=0, warm_start=False)

# %%
print best.score(std2.iloc[:,1:41], std2['STD'])
print best.oob_score_
# Out:
# 0.159927782951
# -0.133034549897

# %%
estimates = pd.DataFrame()
estimates['vars'] = [elem for elem in std2.iloc[:,1:41].columns]
estimates['sig'] = best.feature_importances_
estimates.sort_values(by='sig',ascending=False)
# Out:
#                                  vars       sig
# 18                    PovertySeverity  0.236931
# 36                               TT23  0.200000
# 7                     MadhesiOtherOCB  0.200000
# 11                              Newar  0.200000
# 27                          DPTHepB33  0.163069
# 0                           Foreigner  0.000000
# 30                  Measles911months3  0.000000
# 24                               BCG3  0.000000
# 25                          DPTHepB13  0.000000
# 26                          DPTHepB23  0.000000
# 28              JapeneseEncephalitis3  0.000000
# 29                       Measles12233  0.000000
# 31                            Polio13  0.000000
# 22         Children5yearsmalnourished  0.000000
# 32                            Polio23  0.000000
# 33                            Polio33  0.000000
# 34                               TT13  0.000000
# 35                           TT2plus3  0.000000
# 37                 SanitationCoverage  0.000000
# 38                WaterCoverageSupply  0.000000
# 23                   Withoutsafewater  0.000000
# 20  Deprivationineconomicprovisioning  0.000000
# 21                                HPI  0.000000
# 1                         HillBrahman  0.000000
# 2                        HillChhetree  0.000000
# 3                           HillDalit  0.000000
# 4              MadhesiBrahmanChhetree  0.000000
# 5                        MadhesiDalit  0.000000
# 6                     MadhesiOtherOCA  0.000000
# 8                    MtnHillJanajatiA  0.000000
# 9                    MtnHillJanajatiB  0.000000
# 10                           Musalman  0.000000
# 12                           OtherMPB  0.000000
# 13                     Otherundefined  0.000000
# 14                      TaraiJanajati  0.000000
# 15                     TotalPopCensus  0.000000
# 16                         PovertyGap  0.000000
# 17                   PovertyIncidence  0.000000
# 19                Adultilliteracyrate  0.000000
# 39                                HDI  0.000000

# %%
mse = pd.DataFrame()
mse['district'] = std2['District']
mse['actual'] = std2['STD']
mse['pred'] = best.oob_prediction_
mse['error'] = np.abs(mse['actual']-mse['pred'])
mse.sort_values(by='error')
# Out:
#          district    actual      pred     error
# 35       Lalitpur  0.000000  0.000000  0.000000
# 61        Sarlahi  0.001033  0.001011  0.000022
# 16       Dhankuta  0.001010  0.001033  0.000023
# 55          Rolpa  0.002383  0.002325  0.000058
# 2         Baglung  0.001709  0.001626  0.000083
# 33      Kathmandu  0.001458  0.001563  0.000106
# 53         Rasuwa  0.002633  0.002511  0.000122
# 65     Solukhumbu  0.000132  0.000000  0.000132
# 38      Makwanpur  0.001941  0.001805  0.000136
# 71      Terhathum  0.001427  0.001274  0.000153
# 30     Kanchanpur  0.001268  0.001106  0.000162
# 40         Morang  0.000993  0.001166  0.000173
# 45        Nuwakot  0.001078  0.001303  0.000226
# 5          Bajura  0.002135  0.001846  0.000289
# 3         Baitadi  0.002065  0.001760  0.000305
# 29        Kalikot  0.002169  0.002487  0.000318
# 31     Kapilbastu  0.002051  0.002393  0.000342
# 10        Bhojpur  0.000729  0.001106  0.000377
# 7            Bara  0.001530  0.001941  0.000411
# 63  Sindhupalchok  0.001463  0.001039  0.000423
# 58         Salyan  0.002099  0.002571  0.000471
# 21         Gorkha  0.000793  0.001270  0.000477
# 19          Dolpa  0.002044  0.002531  0.000488
# 54       Rautahat  0.001599  0.002103  0.000504
# 70      Taplejung  0.001444  0.002019  0.000575
# 60        Saptari  0.001524  0.002144  0.000620
# 24           Ilam  0.000365  0.001029  0.000664
# 47          Palpa  0.000685  0.000000  0.000685
# 36        Lamjung  0.000769  0.001501  0.000732
# 22          Gulmi  0.002388  0.001653  0.000735
# ..            ...       ...       ...       ...
# 73       Darchula  0.001216  0.000000  0.001216
# 44    Nawalparasi  0.000076  0.001304  0.001227
# 66        Sunsari  0.000272  0.001501  0.001229
# 62       Sindhuli  0.000540  0.001805  0.001265
# 52      Ramechhap  0.000474  0.001805  0.001331
# 72       Udayapur  0.002463  0.001106  0.001357
# 25       Jajarkot  0.001220  0.002621  0.001401
# 6           Banke  0.002565  0.001106  0.001459
# 64         Siraha  0.000485  0.001982  0.001498
# 50          Parsa  0.000000  0.001513  0.001513
# 48      Panchthar  0.000553  0.002118  0.001565
# 37      Mahottari  0.002957  0.001392  0.001566
# 4         Bajhang  0.000989  0.002570  0.001581
# 57      Rupandehi  0.000000  0.001626  0.001626
# 18        Dolakha  0.002932  0.001304  0.001629
# 49         Parbat  0.000225  0.001867  0.001642
# 0          Achham  0.002750  0.001106  0.001644
# 43         Myagdi  0.000370  0.002109  0.001740
# 28        Kailali  0.001841  0.000000  0.001841
# 32          Kaski  0.002020  0.000000  0.002020
# 15        Dhading  0.003065  0.001033  0.002032
# 56          Rukum  0.002138  0.000000  0.002138
# 26          Jhapa  0.003562  0.001333  0.002230
# 1    Arghakhanchi  0.003334  0.001039  0.002295
# 67        Surkhet  0.004156  0.001644  0.002512
# 8         Bardiya  0.004335  0.001805  0.002530
# 42        Mustang  0.005204  0.002414  0.002790
# 74          Kavre  0.002820  0.000000  0.002820
# 23          Humla  0.008081  0.001626  0.006456
# 12     Dadeldhura  0.008558  0.001749  0.006809
#
# [75 rows x 4 columns]

# %%
estimates[estimates['sig']>.1]['vars'].unique()
# Out:
# array(['MadhesiOtherOCB', 'Newar', 'PovertySeverity', 'DPTHepB33', 'TT23'], dtype=object)

# %%
dtr = DecisionTreeRegressor()
dtr.fit(std2.loc[:,['MadhesiOtherOCB', 'Newar', 'PovertySeverity', 'DPTHepB33', 'TT23']], std2['STD'])
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_split=1e-07,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#            splitter='best')

# %%
dtr.score(std2.loc[:,['MadhesiOtherOCB', 'Newar', 'PovertySeverity', 'DPTHepB33', 'TT23']], std2['STD'])
# Out:
# 0.98398043460033424

# %%
from sklearn.externals.six import StringIO  
from sklearn import tree
from IPython.display import Image  
import pydotplus
dot_data = StringIO()  
tree.export_graphviz(dtr, out_file=dot_data,  
                         feature_names=['MadhesiOtherOCB', 'Newar', 'PovertySeverity', 'DPTHepB33', 'TT23'],  
                         filled=True, rounded=True,  
                         special_characters=True)  
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %% [markdown]
# ### rfr model for hiv
# No parameter tuning

# %%
rfr = RandomForestRegressor(random_state=100,oob_score=True)
rfr.fit(hiv2.iloc[:,1:41], hiv2['HIVAIDS'])
print rfr.score(hiv2.iloc[:,1:41], hiv2['HIVAIDS'])
print rfr.oob_score_
# Out:
# 0.796524090728
# -0.212406588271

# %%
estimates = pd.DataFrame()
estimates['District'] = [elem for elem in hiv2.columns[1:41]]
estimates['sig'] = rfr.feature_importances_
estimates.sort_values(by='sig',ascending=False)
# Out:
#                              District       sig
# 21                                HPI  0.589243
# 30                  Measles911months3  0.100000
# 20  Deprivationineconomicprovisioning  0.100000
# 14                      TaraiJanajati  0.002845
# 16                         PovertyGap  0.002825
# 17                   PovertyIncidence  0.002810
# 22         Children5yearsmalnourished  0.002278
# 37                 SanitationCoverage  0.000000
# 27                          DPTHepB33  0.000000
# 23                   Withoutsafewater  0.000000
# 24                               BCG3  0.000000
# 25                          DPTHepB13  0.000000
# 26                          DPTHepB23  0.000000
# 28              JapeneseEncephalitis3  0.000000
# 36                               TT23  0.000000
# 38                WaterCoverageSupply  0.000000
# 31                            Polio13  0.000000
# 32                            Polio23  0.000000
# 33                            Polio33  0.000000
# 34                               TT13  0.000000
# 35                           TT2plus3  0.000000
# 29                       Measles12233  0.000000
# 0                           Foreigner  0.000000
# 1                         HillBrahman  0.000000
# 8                    MtnHillJanajatiA  0.000000
# 2                        HillChhetree  0.000000
# 3                           HillDalit  0.000000
# 4              MadhesiBrahmanChhetree  0.000000
# 5                        MadhesiDalit  0.000000
# 6                     MadhesiOtherOCA  0.000000
# 7                     MadhesiOtherOCB  0.000000
# 9                    MtnHillJanajatiB  0.000000
# 19                Adultilliteracyrate  0.000000
# 10                           Musalman  0.000000
# 11                              Newar  0.000000
# 12                           OtherMPB  0.000000
# 13                     Otherundefined  0.000000
# 15                     TotalPopCensus  0.000000
# 18                    PovertySeverity  0.000000
# 39                                HDI  0.000000

# %%
mse = pd.DataFrame()
mse['district'] = hiv2['District']
mse['actual'] = hiv2['HIVAIDS']
mse['pred'] = rfr.oob_prediction_
mse['error'] = np.abs(mse['actual']-mse['pred'])
mse.sort_values(by='error')
# Out:
#          district    actual      pred         error
# 42        Mustang  0.000000  0.000000  0.000000e+00
# 29        Kalikot  0.000037  0.000036  9.092935e-08
# 9       Bhaktapur  0.000033  0.000034  1.341164e-06
# 49         Parbat  0.000034  0.000032  1.793894e-06
# 68        Syangja  0.000042  0.000038  3.582990e-06
# 28        Kailali  0.000037  0.000033  4.052615e-06
# 37      Mahottari  0.000032  0.000037  5.339469e-06
# 40         Morang  0.000022  0.000030  8.054369e-06
# 43         Myagdi  0.000026  0.000037  1.027285e-05
# 2         Baglung  0.000026  0.000037  1.054736e-05
# 20           Doti  0.000047  0.000035  1.184107e-05
# 5          Bajura  0.000022  0.000034  1.212763e-05
# 26          Jhapa  0.000050  0.000037  1.305290e-05
# 6           Banke  0.000018  0.000032  1.318659e-05
# 36        Lamjung  0.000024  0.000038  1.399286e-05
# 69         Tanahu  0.000025  0.000039  1.401477e-05
# 52      Ramechhap  0.000025  0.000039  1.408694e-05
# 73       Darchula  0.000015  0.000029  1.445048e-05
# 13        Dailekh  0.000046  0.000031  1.454699e-05
# 71      Terhathum  0.000020  0.000035  1.540958e-05
# 11       Chitawan  0.000048  0.000033  1.547045e-05
# 56          Rukum  0.000053  0.000035  1.778984e-05
# 58         Salyan  0.000016  0.000035  1.885506e-05
# 4         Bajhang  0.000015  0.000036  2.034778e-05
# 18        Dolakha  0.000011  0.000032  2.134160e-05
# 59  Sankhuwasabha  0.000013  0.000036  2.312678e-05
# 44    Nawalparasi  0.000014  0.000037  2.332330e-05
# 15        Dhading  0.000009  0.000034  2.470483e-05
# 21         Gorkha  0.000063  0.000037  2.583466e-05
# 8         Bardiya  0.000007  0.000034  2.660169e-05
# ..            ...       ...       ...           ...
# 72       Udayapur  0.000069  0.000036  3.363670e-05
# 39         Manang  0.000000  0.000034  3.434328e-05
# 19          Dolpa  0.000000  0.000035  3.452131e-05
# 10        Bhojpur  0.000000  0.000035  3.493418e-05
# 63  Sindhupalchok  0.000000  0.000035  3.495101e-05
# 7            Bara  0.000001  0.000037  3.507845e-05
# 14           Dang  0.000000  0.000035  3.521801e-05
# 64         Siraha  0.000000  0.000035  3.525250e-05
# 74          Kavre  0.000003  0.000038  3.535065e-05
# 3         Baitadi  0.000000  0.000035  3.538699e-05
# 17        Dhanusa  0.000001  0.000037  3.544737e-05
# 24           Ilam  0.000000  0.000036  3.551028e-05
# 57      Rupandehi  0.000000  0.000036  3.581253e-05
# 50          Parsa  0.000000  0.000036  3.594164e-05
# 41           Mugu  0.000000  0.000037  3.662767e-05
# 27          Jumla  0.000000  0.000038  3.803636e-05
# 61        Sarlahi  0.000077  0.000038  3.892746e-05
# 65     Solukhumbu  0.000000  0.000039  3.902128e-05
# 12     Dadeldhura  0.000084  0.000033  5.131875e-05
# 62       Sindhuli  0.000122  0.000031  9.054382e-05
# 33      Kathmandu  0.000139  0.000043  9.630165e-05
# 55          Rolpa  0.000147  0.000040  1.073489e-04
# 32          Kaski  0.000144  0.000034  1.101169e-04
# 45        Nuwakot  0.000213  0.000031  1.815504e-04
# 47          Palpa  0.000613  0.000029  5.838725e-04
# 25       Jajarkot  0.000076  0.000866  7.896201e-04
# 51        Pyuthan  0.000000  0.001146  1.146173e-03
# 54       Rautahat  0.000019  0.002031  2.012356e-03
# 0          Achham  0.003360  0.000034  3.325331e-03
# 23          Humla  0.004699  0.000032  4.667004e-03
#
# [75 rows x 4 columns]

# %% [markdown]
# Parameter tuning

# %%
#https://www.analyticsvidhya.com/blog/2015/06/tuning-random-forest-model/
model = RandomForestRegressor()
vals = {'n_estimators':[1, 5, 9],'max_features':[.3, .4, .5], 'min_samples_leaf':[10, 15, 20], \
       'n_jobs':[-1], 'oob_score':[True], 'random_state':[1, 2, 3]}
grid = GridSearchCV(estimator=model, param_grid=vals)
grid.fit(hiv2.iloc[:,1:41], hiv2['HIVAIDS'])
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'oob_score': [True], 'n_jobs': [-1], 'min_samples_leaf': [10, 15, 20], 'n_estimators': [1, 5, 9], 'random_state': [1, 2, 3], 'max_features': [0.3, 0.4, 0.5]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=0)

# %%
print grid.best_estimator_.n_estimators
print grid.best_estimator_.max_features
print grid.best_estimator_.min_samples_leaf
print grid.best_estimator_.random_state
print grid.best_score_
# Out:
# 5
# 0.4
# 15
# 2
# -1.56875318198

# %%
best = grid.best_estimator_
best.fit(hiv2.iloc[:,1:41], hiv2['HIVAIDS'])
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=0.4, max_leaf_nodes=None, min_impurity_split=1e-07,
#            min_samples_leaf=15, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=5, n_jobs=-1,
#            oob_score=True, random_state=2, verbose=0, warm_start=False)

# %%
print best.score(hiv2.iloc[:,1:41], hiv2['HIVAIDS'])
print best.oob_score_
# Out:
# 0.0351268556923
# -0.0115503212967

# %%
estimates = pd.DataFrame()
estimates['vars'] = [elem for elem in hiv2.iloc[:,1:41].columns]
estimates['sig'] = best.feature_importances_
estimates.sort_values(by='sig',ascending=False)
# Out:
#                                  vars  sig
# 31                            Polio13  0.2
# 30                  Measles911months3  0.2
# 23                   Withoutsafewater  0.2
# 9                    MtnHillJanajatiB  0.2
# 24                               BCG3  0.0
# 25                          DPTHepB13  0.0
# 26                          DPTHepB23  0.0
# 27                          DPTHepB33  0.0
# 28              JapeneseEncephalitis3  0.0
# 29                       Measles12233  0.0
# 0                           Foreigner  0.0
# 21                                HPI  0.0
# 32                            Polio23  0.0
# 33                            Polio33  0.0
# 34                               TT13  0.0
# 35                           TT2plus3  0.0
# 36                               TT23  0.0
# 37                 SanitationCoverage  0.0
# 38                WaterCoverageSupply  0.0
# 22         Children5yearsmalnourished  0.0
# 20  Deprivationineconomicprovisioning  0.0
# 1                         HillBrahman  0.0
# 10                           Musalman  0.0
# 2                        HillChhetree  0.0
# 3                           HillDalit  0.0
# 4              MadhesiBrahmanChhetree  0.0
# 5                        MadhesiDalit  0.0
# 6                     MadhesiOtherOCA  0.0
# 7                     MadhesiOtherOCB  0.0
# 8                    MtnHillJanajatiA  0.0
# 11                              Newar  0.0
# 19                Adultilliteracyrate  0.0
# 12                           OtherMPB  0.0
# 13                     Otherundefined  0.0
# 14                      TaraiJanajati  0.0
# 15                     TotalPopCensus  0.0
# 16                         PovertyGap  0.0
# 17                   PovertyIncidence  0.0
# 18                    PovertySeverity  0.0
# 39                                HDI  0.0

# %%
mse = pd.DataFrame()
mse['district'] = hiv2['District']
mse['actual'] = hiv2['HIVAIDS']
mse['pred'] = best.oob_prediction_
mse['error'] = np.abs(mse['actual']-mse['pred'])
mse.sort_values(by='error')
# Out:
#          district    actual      pred     error
# 1    Arghakhanchi  0.000000  0.000000  0.000000
# 16       Dhankuta  0.000000  0.000000  0.000000
# 70      Taplejung  0.000000  0.000000  0.000000
# 57      Rupandehi  0.000000  0.000000  0.000000
# 27          Jumla  0.000000  0.000000  0.000000
# 52      Ramechhap  0.000025  0.000021  0.000004
# 40         Morang  0.000022  0.000026  0.000004
# 28        Kailali  0.000037  0.000033  0.000005
# 54       Rautahat  0.000019  0.000025  0.000006
# 71      Terhathum  0.000020  0.000026  0.000007
# 18        Dolakha  0.000011  0.000020  0.000009
# 9       Bhaktapur  0.000033  0.000023  0.000010
# 59  Sankhuwasabha  0.000013  0.000000  0.000013
# 15        Dhading  0.000009  0.000023  0.000014
# 6           Banke  0.000018  0.000033  0.000014
# 44    Nawalparasi  0.000014  0.000029  0.000015
# 30     Kanchanpur  0.000007  0.000023  0.000016
# 49         Parbat  0.000034  0.000017  0.000017
# 53         Rasuwa  0.000000  0.000017  0.000017
# 31     Kapilbastu  0.000000  0.000017  0.000017
# 66        Sunsari  0.000001  0.000020  0.000019
# 11       Chitawan  0.000048  0.000029  0.000020
# 42        Mustang  0.000000  0.000020  0.000020
# 24           Ilam  0.000000  0.000020  0.000020
# 74          Kavre  0.000003  0.000024  0.000021
# 50          Parsa  0.000000  0.000021  0.000021
# 34        Khotang  0.000005  0.000026  0.000021
# 39         Manang  0.000000  0.000023  0.000023
# 46    Okhaldhunga  0.000000  0.000023  0.000023
# 36        Lamjung  0.000024  0.000000  0.000024
# ..            ...       ...       ...       ...
# 17        Dhanusa  0.000001  0.000083  0.000081
# 43         Myagdi  0.000026  0.000112  0.000086
# 58         Salyan  0.000016  0.000108  0.000092
# 55          Rolpa  0.000147  0.000239  0.000092
# 62       Sindhuli  0.000122  0.000029  0.000093
# 2         Baglung  0.000026  0.000129  0.000103
# 51        Pyuthan  0.000000  0.000114  0.000114
# 32          Kaski  0.000144  0.000020  0.000124
# 48      Panchthar  0.000000  0.000130  0.000130
# 19          Dolpa  0.000000  0.000132  0.000132
# 35       Lalitpur  0.000000  0.000134  0.000134
# 33      Kathmandu  0.000139  0.000000  0.000139
# 12     Dadeldhura  0.000084  0.000239  0.000155
# 73       Darchula  0.000015  0.000175  0.000160
# 20           Doti  0.000047  0.000227  0.000180
# 26          Jhapa  0.000050  0.000239  0.000188
# 45        Nuwakot  0.000213  0.000021  0.000192
# 5          Bajura  0.000022  0.000222  0.000199
# 68        Syangja  0.000042  0.000241  0.000199
# 67        Surkhet  0.000000  0.000225  0.000225
# 10        Bhojpur  0.000000  0.000239  0.000239
# 14           Dang  0.000000  0.000240  0.000240
# 4         Bajhang  0.000015  0.000299  0.000283
# 25       Jajarkot  0.000076  0.000453  0.000377
# 56          Rukum  0.000053  0.000453  0.000400
# 22          Gulmi  0.000004  0.000453  0.000449
# 64         Siraha  0.000000  0.000453  0.000453
# 47          Palpa  0.000613  0.000025  0.000588
# 0          Achham  0.003360  0.000239  0.003120
# 23          Humla  0.004699  0.000083  0.004617
#
# [75 rows x 4 columns]

# %% [markdown]
# ### decision tree for hiv with significant random forest vars

# %%
sig = estimates[estimates['sig'] >=.2]
sig
# Out:
#                  vars  sig
# 9    MtnHillJanajatiB  0.2
# 23   Withoutsafewater  0.2
# 30  Measles911months3  0.2
# 31            Polio13  0.2

# %%
dtr = DecisionTreeRegressor()
dtr.fit(hiv2.loc[:,['MtnHillJanajatiB', 'Withoutsafewater', 'Measles911months3', 'Polio13']], hiv2['HIVAIDS'])
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_split=1e-07,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#            splitter='best')

# %%
dtr.score(hiv2.loc[:,['MtnHillJanajatiB', 'Withoutsafewater', 'Measles911months3', 'Polio13']], hiv2['HIVAIDS'])
# Out:
# 0.98577092861989879

# %%
from sklearn.externals.six import StringIO  
from sklearn import tree
from IPython.display import Image  
import pydotplus
dot_data = StringIO()  
tree.export_graphviz(dtr, out_file=dot_data,  
                         feature_names=['MtnHillJanajatiB', 'Withoutsafewater', 'Measles911months3', 'Polio13'],  
                         filled=True, rounded=True,  
                         special_characters=True)  
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

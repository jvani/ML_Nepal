# %%
import pandas as pd
import geopandas as gpd
import os
# %pylab inline
import matplotlib.pylab as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
master = pd.read_csv('Data/master.csv')

# %%
master.head()
# Out:
#      Unnamed: 0  Foreigner  Hill Brahman  Hill Chhetree  Hill Dalit  \
# 0        Achham   0.000000      0.102036       0.581749    0.135158
# 1  Arghakhanchi   0.000000      0.327665       0.193248    0.209020
# 2       Baglung   0.000045      0.195385       0.205601    0.263230
# 3       Baitadi   0.000052      0.185498       0.603899    0.083153
# 4       Bajhang   0.000077      0.101953       0.726490    0.113103
#
#    Madhesi Brahman/Chhetree  Madhesi Dalit  Madhesi Other - OC A  \
# 0                  0.000101       0.000000              0.004921
# 1                  0.001604       0.000066              0.001058
# 2                  0.001165       0.000000              0.000927
# 3                  0.001610       0.000128              0.052499
# 4                  0.000497       0.000102              0.000277
#
#    Madhesi Other - OC B  Mtn/Hill Janajati A    ...      Tetanus  \
# 0                   0.0             0.006921    ...          0.0
# 1                   0.0             0.193349    ...          0.0
# 2                   0.0             0.308176    ...          4.0
# 3                   0.0             0.003870    ...          6.0
# 4                   0.0             0.002055    ...          1.0
#
#    Tuberculosis  Whooping cough  Alcoholism  Anxiety (Neurosis  \
# 0          62.0            16.0         9.0              311.0
# 1          47.0             0.0        56.0              382.0
# 2          40.0             0.0       102.0              594.0
# 3         141.0             1.0        51.0              132.0
# 4          90.0             4.0        20.0              246.0
#
#    Conversive disorder\n(Hysteria)  Depression  Epilesy  Mental retardation  \
# 0                             39.0       381.0    108.0                 5.0
# 1                             32.0       267.0     20.0                 7.0
# 2                             45.0       302.0     86.0               101.0
# 3                             15.0       129.0      5.0                44.0
# 4                             34.0       167.0     26.0                 7.0
#
#    Psychosis
# 0       36.0
# 1       66.0
# 2      130.0
# 3       26.0
# 4       45.0
#
# [5 rows x 76 columns]

# %%
master.columns
# Out:
# Index([u'Unnamed: 0', u'Foreigner', u'Hill Brahman', u'Hill Chhetree',
#        u'Hill Dalit', u'Madhesi Brahman/Chhetree', u'Madhesi Dalit',
#        u'Madhesi Other - OC A', u'Madhesi Other - OC B',
#        u'Mtn/Hill Janajati A', u'Mtn/Hill Janajati B', u'Musalman', u'Newar',
#        u'Other (MPB)', u'Other undefined', u'Tarai Janajati',
#        u'Total Pop Census', u'Population', u'Poverty Gap',
#        u'Poverty Incidence', u'Poverty Severity',
#        u'Standard Error of Poverty Gap',
#        u'Standard Error of Poverty Incidence',
#        u'Standard Error of Poverty Severity', u'Adult illiteracy rate',
#        u'Deprivation in economic provisioning', u'HPI',
#        u'Percentage of People not expected to survive age 40',
#        u'Percentage of children under age five who are malnurished',
#        u'Percentage without safe water', u'BCG3', u'DPT-HepB 1 3',
#        u'DPT-HepB 2 3', u'DPT-HepB 3 3', u'Japenese Encephalitis 3',
#        u'Measles 12-23 3', u'Measles 9-11 months 3', u'Polio13', u'Polio23',
#        u'Polio33', u'TT 1 3', u'TT 2+ 3', u'TT23', u'Sanitation Coverage (%',
#        u'Total Population', u'Water Coverage Supply (%)', u'Zone',
#        u'Geographical Region', u'Development Region', u'HDI ', u'Zone.1',
#        u'Geographical Region.1', u'Development Region.1',
#        u'Sex Ratio (male per 100 female)', u'Confirmed Meningitis 3',
#        u'HIV/AIDS3', u'Leprosy3', u'STD/STI3', u'Acute Flacid Paralysis',
#        u'Chicken pox', u'Diptheria', u'Hepatatis-B', u'Measles', u'Mumps',
#        u'Neonatal Tetanus', u'Rubella', u'Tetanus', u'Tuberculosis',
#        u'Whooping cough', u'Alcoholism', u'Anxiety (Neurosis',
#        u'Conversive disorder\n(Hysteria)', u'Depression', u'Epilesy',
#        u'Mental retardation', u'Psychosis'],
#       dtype='object')

# %%
master = master.rename(columns={'Unnamed: 0':'District'})

# %%
master =  master.drop(['Population', 'Standard Error of Poverty Gap', 'Standard Error of Poverty Incidence', \
                      'Standard Error of Poverty Severity', 'Total Population', 'Zone', 'Geographical Region', \
                       'Development Region', 'Zone.1', 'Geographical Region.1', 'Development Region.1'], axis=1)

# %%
master.columns
# Out:
# Index([u'District', u'Foreigner', u'Hill Brahman', u'Hill Chhetree',
#        u'Hill Dalit', u'Madhesi Brahman/Chhetree', u'Madhesi Dalit',
#        u'Madhesi Other - OC A', u'Madhesi Other - OC B',
#        u'Mtn/Hill Janajati A', u'Mtn/Hill Janajati B', u'Musalman', u'Newar',
#        u'Other (MPB)', u'Other undefined', u'Tarai Janajati',
#        u'Total Pop Census', u'Poverty Gap', u'Poverty Incidence',
#        u'Poverty Severity', u'Adult illiteracy rate',
#        u'Deprivation in economic provisioning', u'HPI',
#        u'Percentage of People not expected to survive age 40',
#        u'Percentage of children under age five who are malnurished',
#        u'Percentage without safe water', u'BCG3', u'DPT-HepB 1 3',
#        u'DPT-HepB 2 3', u'DPT-HepB 3 3', u'Japenese Encephalitis 3',
#        u'Measles 12-23 3', u'Measles 9-11 months 3', u'Polio13', u'Polio23',
#        u'Polio33', u'TT 1 3', u'TT 2+ 3', u'TT23', u'Sanitation Coverage (%',
#        u'Water Coverage Supply (%)', u'HDI ',
#        u'Sex Ratio (male per 100 female)', u'Confirmed Meningitis 3',
#        u'HIV/AIDS3', u'Leprosy3', u'STD/STI3', u'Acute Flacid Paralysis',
#        u'Chicken pox', u'Diptheria', u'Hepatatis-B', u'Measles', u'Mumps',
#        u'Neonatal Tetanus', u'Rubella', u'Tetanus', u'Tuberculosis',
#        u'Whooping cough', u'Alcoholism', u'Anxiety (Neurosis',
#        u'Conversive disorder\n(Hysteria)', u'Depression', u'Epilesy',
#        u'Mental retardation', u'Psychosis'],
#       dtype='object')

# %%
k = [i for i in range(16,len(master.columns))]

# %%
master.iloc[:,k].head()
# Out:
#    Total Pop Census  Poverty Gap  Poverty Incidence  Poverty Severity  \
# 0          257477.0        0.127              0.472             0.047
# 1          197632.0        0.069              0.288             0.024
# 2          268613.0        0.053              0.229             0.018
# 3          250898.0        0.123              0.457             0.046
# 4          195159.0        0.162              0.568             0.063
#
#    Adult illiteracy rate  Deprivation in economic provisioning    HPI  \
# 0                  54.92                                 51.76  46.68
# 1                  34.43                                 27.24  27.37
# 2                  34.46                                 27.01  27.33
# 3                  45.15                                 45.38  39.58
# 4                  54.97                                 48.05  45.32
#
#    Percentage of People not expected to survive age 40  \
# 0                                               9.50
# 1                                               7.71
# 2                                               8.52
# 3                                               8.14
# 4                                              12.81
#
#    Percentage of children under age five who are malnurished  \
# 0                                               59.2
# 1                                               31.0
# 2                                               42.9
# 3                                               59.2
# 4                                               63.2
#
#    Percentage without safe water    ...      Tetanus  Tuberculosis  \
# 0                          44.31    ...          0.0          62.0
# 1                          23.48    ...          0.0          47.0
# 2                          11.12    ...          4.0          40.0
# 3                          31.57    ...          6.0         141.0
# 4                          32.91    ...          1.0          90.0
#
#    Whooping cough  Alcoholism  Anxiety (Neurosis  \
# 0            16.0         9.0              311.0
# 1             0.0        56.0              382.0
# 2             0.0       102.0              594.0
# 3             1.0        51.0              132.0
# 4             4.0        20.0              246.0
#
#    Conversive disorder\n(Hysteria)  Depression  Epilesy  Mental retardation  \
# 0                             39.0       381.0    108.0                 5.0
# 1                             32.0       267.0     20.0                 7.0
# 2                             45.0       302.0     86.0               101.0
# 3                             15.0       129.0      5.0                44.0
# 4                             34.0       167.0     26.0                 7.0
#
#    Psychosis
# 0       36.0
# 1       66.0
# 2      130.0
# 3       26.0
# 4       45.0
#
# [5 rows x 49 columns]

# %%
master['Percentage of People not expected to survive age 40'] = master['Percentage of People not expected to survive age 40']*.01
master['Percentage of children under age five who are malnurished'] = master['Percentage of children under age five who are malnurished']*.01
master['Percentage without safe water'] = master['Percentage without safe water']*.01

# %%
master.iloc[:,k].head()
# Out:
#    Total Pop Census  Poverty Gap  Poverty Incidence  Poverty Severity  \
# 0          257477.0        0.127              0.472             0.047
# 1          197632.0        0.069              0.288             0.024
# 2          268613.0        0.053              0.229             0.018
# 3          250898.0        0.123              0.457             0.046
# 4          195159.0        0.162              0.568             0.063
#
#    Adult illiteracy rate  Deprivation in economic provisioning    HPI  \
# 0                  54.92                                 51.76  46.68
# 1                  34.43                                 27.24  27.37
# 2                  34.46                                 27.01  27.33
# 3                  45.15                                 45.38  39.58
# 4                  54.97                                 48.05  45.32
#
#    Percentage of People not expected to survive age 40  \
# 0                                             0.0950
# 1                                             0.0771
# 2                                             0.0852
# 3                                             0.0814
# 4                                             0.1281
#
#    Percentage of children under age five who are malnurished  \
# 0                                              0.592
# 1                                              0.310
# 2                                              0.429
# 3                                              0.592
# 4                                              0.632
#
#    Percentage without safe water    ...      Tetanus  Tuberculosis  \
# 0                         0.4431    ...          0.0          62.0
# 1                         0.2348    ...          0.0          47.0
# 2                         0.1112    ...          4.0          40.0
# 3                         0.3157    ...          6.0         141.0
# 4                         0.3291    ...          1.0          90.0
#
#    Whooping cough  Alcoholism  Anxiety (Neurosis  \
# 0            16.0         9.0              311.0
# 1             0.0        56.0              382.0
# 2             0.0       102.0              594.0
# 3             1.0        51.0              132.0
# 4             4.0        20.0              246.0
#
#    Conversive disorder\n(Hysteria)  Depression  Epilesy  Mental retardation  \
# 0                             39.0       381.0    108.0                 5.0
# 1                             32.0       267.0     20.0                 7.0
# 2                             45.0       302.0     86.0               101.0
# 3                             15.0       129.0      5.0                44.0
# 4                             34.0       167.0     26.0                 7.0
#
#    Psychosis
# 0       36.0
# 1       66.0
# 2      130.0
# 3       26.0
# 4       45.0
#
# [5 rows x 49 columns]

# %%
master.columns
# Out:
# Index([u'District', u'Foreigner', u'Hill Brahman', u'Hill Chhetree',
#        u'Hill Dalit', u'Madhesi Brahman/Chhetree', u'Madhesi Dalit',
#        u'Madhesi Other - OC A', u'Madhesi Other - OC B',
#        u'Mtn/Hill Janajati A', u'Mtn/Hill Janajati B', u'Musalman', u'Newar',
#        u'Other (MPB)', u'Other undefined', u'Tarai Janajati',
#        u'Total Pop Census', u'Poverty Gap', u'Poverty Incidence',
#        u'Poverty Severity', u'Adult illiteracy rate',
#        u'Deprivation in economic provisioning', u'HPI',
#        u'Percentage of People not expected to survive age 40',
#        u'Percentage of children under age five who are malnurished',
#        u'Percentage without safe water', u'BCG3', u'DPT-HepB 1 3',
#        u'DPT-HepB 2 3', u'DPT-HepB 3 3', u'Japenese Encephalitis 3',
#        u'Measles 12-23 3', u'Measles 9-11 months 3', u'Polio13', u'Polio23',
#        u'Polio33', u'TT 1 3', u'TT 2+ 3', u'TT23', u'Sanitation Coverage (%',
#        u'Water Coverage Supply (%)', u'HDI ',
#        u'Sex Ratio (male per 100 female)', u'Confirmed Meningitis 3',
#        u'HIV/AIDS3', u'Leprosy3', u'STD/STI3', u'Acute Flacid Paralysis',
#        u'Chicken pox', u'Diptheria', u'Hepatatis-B', u'Measles', u'Mumps',
#        u'Neonatal Tetanus', u'Rubella', u'Tetanus', u'Tuberculosis',
#        u'Whooping cough', u'Alcoholism', u'Anxiety (Neurosis',
#        u'Conversive disorder\n(Hysteria)', u'Depression', u'Epilesy',
#        u'Mental retardation', u'Psychosis'],
#       dtype='object')

# %%
k = [i for i in range(26,len(master.columns))]

# %%
master.iloc[:,k].head()
# Out:
#      BCG3  DPT-HepB 1 3  DPT-HepB 2 3  DPT-HepB 3 3  Japenese Encephalitis 3  \
# 0  7676.0        7639.0        7616.0        7581.0                      0.0
# 1  4649.0        4890.0        4601.0        4699.0                      0.0
# 2  6612.0        6609.0        6371.0        6544.0                      0.0
# 3  6452.0        6431.0        6413.0        6417.0                      0.0
# 4  5322.0        5252.0        5214.0        5182.0                      0.0
#
#    Measles 12-23 3  Measles 9-11 months 3  Polio13  Polio23  Polio33  \
# 0            123.0                 7581.0   7639.0   7616.0   7581.0
# 1             18.0                 4616.0   4916.0   4620.0   4703.0
# 2              0.0                 6342.0   6609.0   6371.0   6544.0
# 3            396.0                 6033.0   6134.0   6342.0   6417.0
# 4             86.0                 5081.0   5195.0   5118.0   5125.0
#
#      ...      Tetanus  Tuberculosis  Whooping cough  Alcoholism  \
# 0    ...          0.0          62.0            16.0         9.0
# 1    ...          0.0          47.0             0.0        56.0
# 2    ...          4.0          40.0             0.0       102.0
# 3    ...          6.0         141.0             1.0        51.0
# 4    ...          1.0          90.0             4.0        20.0
#
#    Anxiety (Neurosis  Conversive disorder\n(Hysteria)  Depression  Epilesy  \
# 0              311.0                             39.0       381.0    108.0
# 1              382.0                             32.0       267.0     20.0
# 2              594.0                             45.0       302.0     86.0
# 3              132.0                             15.0       129.0      5.0
# 4              246.0                             34.0       167.0     26.0
#
#    Mental retardation  Psychosis
# 0                 5.0       36.0
# 1                 7.0       66.0
# 2               101.0      130.0
# 3                44.0       26.0
# 4                 7.0       45.0
#
# [5 rows x 39 columns]

# %%
master.iloc[:,k] = master.iloc[:,k].div(master['Total Pop Census'],axis=0)

# %%
master.head()
# Out:
#        District  Foreigner  Hill Brahman  Hill Chhetree  Hill Dalit  \
# 0        Achham   0.000000      0.102036       0.581749    0.135158
# 1  Arghakhanchi   0.000000      0.327665       0.193248    0.209020
# 2       Baglung   0.000045      0.195385       0.205601    0.263230
# 3       Baitadi   0.000052      0.185498       0.603899    0.083153
# 4       Bajhang   0.000077      0.101953       0.726490    0.113103
#
#    Madhesi Brahman/Chhetree  Madhesi Dalit  Madhesi Other - OC A  \
# 0                  0.000101       0.000000              0.004921
# 1                  0.001604       0.000066              0.001058
# 2                  0.001165       0.000000              0.000927
# 3                  0.001610       0.000128              0.052499
# 4                  0.000497       0.000102              0.000277
#
#    Madhesi Other - OC B  Mtn/Hill Janajati A    ...       Tetanus  \
# 0                   0.0             0.006921    ...      0.000000
# 1                   0.0             0.193349    ...      0.000000
# 2                   0.0             0.308176    ...      0.000015
# 3                   0.0             0.003870    ...      0.000024
# 4                   0.0             0.002055    ...      0.000005
#
#    Tuberculosis  Whooping cough  Alcoholism  Anxiety (Neurosis  \
# 0      0.000241        0.000062    0.000035           0.001208
# 1      0.000238        0.000000    0.000283           0.001933
# 2      0.000149        0.000000    0.000380           0.002211
# 3      0.000562        0.000004    0.000203           0.000526
# 4      0.000461        0.000020    0.000102           0.001261
#
#    Conversive disorder\n(Hysteria)  Depression   Epilesy  Mental retardation  \
# 0                         0.000151    0.001480  0.000419            0.000019
# 1                         0.000162    0.001351  0.000101            0.000035
# 2                         0.000168    0.001124  0.000320            0.000376
# 3                         0.000060    0.000514  0.000020            0.000175
# 4                         0.000174    0.000856  0.000133            0.000036
#
#    Psychosis
# 0   0.000140
# 1   0.000334
# 2   0.000484
# 3   0.000104
# 4   0.000231
#
# [5 rows x 65 columns]

# %%
master = master.rename(columns={'Percentage of People not expected to survive age 40':'People not expected to survive age 40', \
                                'Percentage of children under age five who are malnurished':'Children <5 years malnourished', \
                                'Percentage without safe water':'Without safe water'})

# %%
master.head()
# Out:
#        District  Foreigner  Hill Brahman  Hill Chhetree  Hill Dalit  \
# 0        Achham   0.000000      0.102036       0.581749    0.135158
# 1  Arghakhanchi   0.000000      0.327665       0.193248    0.209020
# 2       Baglung   0.000045      0.195385       0.205601    0.263230
# 3       Baitadi   0.000052      0.185498       0.603899    0.083153
# 4       Bajhang   0.000077      0.101953       0.726490    0.113103
#
#    Madhesi Brahman/Chhetree  Madhesi Dalit  Madhesi Other - OC A  \
# 0                  0.000101       0.000000              0.004921
# 1                  0.001604       0.000066              0.001058
# 2                  0.001165       0.000000              0.000927
# 3                  0.001610       0.000128              0.052499
# 4                  0.000497       0.000102              0.000277
#
#    Madhesi Other - OC B  Mtn/Hill Janajati A    ...       Tetanus  \
# 0                   0.0             0.006921    ...      0.000000
# 1                   0.0             0.193349    ...      0.000000
# 2                   0.0             0.308176    ...      0.000015
# 3                   0.0             0.003870    ...      0.000024
# 4                   0.0             0.002055    ...      0.000005
#
#    Tuberculosis  Whooping cough  Alcoholism  Anxiety (Neurosis  \
# 0      0.000241        0.000062    0.000035           0.001208
# 1      0.000238        0.000000    0.000283           0.001933
# 2      0.000149        0.000000    0.000380           0.002211
# 3      0.000562        0.000004    0.000203           0.000526
# 4      0.000461        0.000020    0.000102           0.001261
#
#    Conversive disorder\n(Hysteria)  Depression   Epilesy  Mental retardation  \
# 0                         0.000151    0.001480  0.000419            0.000019
# 1                         0.000162    0.001351  0.000101            0.000035
# 2                         0.000168    0.001124  0.000320            0.000376
# 3                         0.000060    0.000514  0.000020            0.000175
# 4                         0.000174    0.000856  0.000133            0.000036
#
#    Psychosis
# 0   0.000140
# 1   0.000334
# 2   0.000484
# 3   0.000104
# 4   0.000231
#
# [5 rows x 65 columns]

# %%
master = master.fillna(0)

# %%
cols = [elem for elem in master.iloc[:,1:].columns]
for elem in cols:
    plt.figure(figsize=(8,8))
    plt.hist(master[elem])
    plt.title('histogram plot of ' + elem, fontsize=12)
    plt.xlabel(elem, fontsize=12)
    plt.ylabel('volume of data points', fontsize=12)
# Out:
# /Users/kristikorsberg/devel/venv/lib/python2.7/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
master.to_csv('Data/master_updated.csv')
